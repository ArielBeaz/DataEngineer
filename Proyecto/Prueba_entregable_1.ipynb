# %%
import requests
import os
import json
from dotenv import load_dotenv

load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       2 import os
#       3 import json
# ----> 4 from dotenv import load_dotenv
#       6 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
YOUTUBE_API_KEY = os.getenv('YOUTUBE_API_KEY')
API_URL = 'https://www.googleapis.com/youtube/v3/videos'

params = {
       'part': 'snippet,statistics,contentDetails',
       'chart': 'mostPopular',
       'regionCode': 'CL',
       'maxResults': 10, 
       'key': YOUTUBE_API_KEY}

response = requests.get(API_URL, params=params)


data = response.json()

# %%
data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'xdpL4jexQawS_yLU2hVxugLAnc4',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'JRJrxp9FEUNPalxD6KZ7TyxkFVY',
#    'id': 'RJw3Y-3EBFo',
#    'snippet': {'publishedAt': '2024-08-01T09:01:54Z',
#     'channelId': 'UCooVYzDxdwTtGYAkcPmOgOw',
#     'title': 'Brawl Stars Animation: PAINT BRAWL STARTS NOW!',
#     'description': "\U0001fae7 WE'RE BRAWLING IN THE DEEP! \U0001fae7\n\n🎨 The new Paint Brawl Game Mode is here!\n\U0001fabc Jellyfish Sandy as the Brawl Pass Skin!\n🦑 Brawl Pass Plus = Neon & Glowing Jellyfish Sandy + the 'Vandal' Title\n🐚 Shell Blaster Gale in Ranked Starr Drops!\n🦞 Clancy is out now in the Starr Road\n\nDownload NOW!! ►► https://supr.cl/2K62CZG\nSubscribe!! ►► https://supr.cl/subscribe\n\nAn epic battle royale made for mobile! Play with friends or solo across various game modes in under three minutes.\n\nUnlock and upgrade dozens of Brawlers with powerful Super abilities, Star Powers, Gadgets and Gears! \nCollect unique skins to stand out and show off. Battle in a variety of mysterious locations within the Brawliverse!\n\nBATTLE IN MULTIPLE GAME MODES\n- Gem Grab (3v3): Team up and out-strategize the opposing team. Collect and hold 10 gems to win, but get fragged and lose your gems.\n- Showdown (Solo/Duo): A battle royale style fight for survival. Collect power ups for your Brawler. Grab a friend or play solo - be the last Brawler standing in the rowdiest battle royale yet. Winner take all!\n- Brawl Ball (3v3): It’s a whole new Brawl game! Show off your soccer/football skills and score two goals before the other team. There are no red cards here.\n- Bounty (3v3): Take out opponents to earn stars, but don’t let them pick you off. The squad with the most stars wins the match!\n- Heist (3v3): Protect your team’s safe and try to crack open your opponents’. Navigate the map to sneak, blast and blow your way clear to the enemies treasure.\n- Special Events: Limited time special PvE and PvP game modes.\n\nUNLOCK AND UPGRADE BRAWLERS\nCollect and upgrade a variety of Brawlers with powerful Super abilities, Star Powers, Gadgets! and Gears! Level them up and collect unique skins!\n\nBRAWL PASS\nComplete quests, open Brawl Boxes, earn Gems, pins and an exclusive Brawl Pass skin! Fresh content every season!\n\nBECOME THE STAR PLAYER\nClimb the local and regional leaderboards to prove you’re the greatest Brawler of them all!\n\nCONSTANTLY EVOLVING\nLook out for new Brawlers, skins, maps, special events and games modes in the future!\n\nPLEASE NOTE! Brawl Stars is free to download and play, however, some game items can also be purchased for real money. If you don’t want to use this feature, please disable in-app purchases in your device’s settings. Also, under our Terms of Service and Privacy Policy, you must be at least 9 years of age to play or download Brawl Stars.\n\nFeatures:\n- Team up for real-time 3v3 battles against players from across the world\n- A fast-paced multiplayer battle royale mode made for mobile\n- Unlock and collect new, powerful Brawlers - each with a signature attack and Super ability\n- New events and game modes daily\n- Battle solo or with friends\n- Climb to the top of the leaderboards in global and local rankings\n- Join or start your own Club with fellow players to share tips and battle together\n- Customize Brawlers with unlockable skins\n- Player-designed maps offer challenging new terrain to master\n\nFrom the makers of Clash of Clans, Clash Royale and Boom Beach!\n\nSupport:\nContact us in-game via Settings, Help and Support — or visit http://supercell.helpshift.com/a/brawl-stars/\n\nPrivacy Policy:\nhttp://supercell.com/en/privacy-policy/\n\nTerms of Service:\nhttp://supercell.com/en/terms-of-service/\n\nParent’s Guide:\nhttp://supercell.com/en/parents/\n\n#brawlstars #paintbrawl",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/RJw3Y-3EBFo/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/RJw3Y-3EBFo/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/RJw3Y-3EBFo/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/RJw3Y-3EBFo/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/RJw3Y-3EBFo/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Brawl Stars',
#     'tags': ['brawl stars',
#      'mobile game',
#      'mobile strategy game',
#      'mobile rpg',
#      'mobile battle royale',
#      'battle royale',
#      'supercell game',
#      'Paint Brawl',
#      'Deep Sea Brawl',
#      'Otis',
#      'Hank',
#      'Gale',
#      'Sprout',
#      'Clancy',
#      'Jacky',
#      'Brawl Pass',
#      'New Season',
#      'brawl talk'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'Brawl Stars Animation: PAINT BRAWL STARTS NOW!',
#      'description': "\U0001fae7 WE'RE BRAWLING IN THE DEEP! \U0001fae7\n\n🎨 The new Paint Brawl Game Mode is here!\n\U0001fabc Jellyfish Sandy as the Brawl Pass Skin!\n🦑 Brawl Pass Plus = Neon & Glowing Jellyfish Sandy + the 'Vandal' Title\n🐚 Shell Blaster Gale in Ranked Starr Drops!\n🦞 Clancy is out now in the Starr Road\n\nDownload NOW!! ►► https://supr.cl/2K62CZG\nSubscribe!! ►► https://supr.cl/subscribe\n\nAn epic battle royale made for mobile! Play with friends or solo across various game modes in under three minutes.\n\nUnlock and upgrade dozens of Brawlers with powerful Super abilities, Star Powers, Gadgets and Gears! \nCollect unique skins to stand out and show off. Battle in a variety of mysterious locations within the Brawliverse!\n\nBATTLE IN MULTIPLE GAME MODES\n- Gem Grab (3v3): Team up and out-strategize the opposing team. Collect and hold 10 gems to win, but get fragged and lose your gems.\n- Showdown (Solo/Duo): A battle royale style fight for survival. Collect power ups for your Brawler. Grab a friend or play solo - be the last Brawler standing in the rowdiest battle royale yet. Winner take all!\n- Brawl Ball (3v3): It’s a whole new Brawl game! Show off your soccer/football skills and score two goals before the other team. There are no red cards here.\n- Bounty (3v3): Take out opponents to earn stars, but don’t let them pick you off. The squad with the most stars wins the match!\n- Heist (3v3): Protect your team’s safe and try to crack open your opponents’. Navigate the map to sneak, blast and blow your way clear to the enemies treasure.\n- Special Events: Limited time special PvE and PvP game modes.\n\nUNLOCK AND UPGRADE BRAWLERS\nCollect and upgrade a variety of Brawlers with powerful Super abilities, Star Powers, Gadgets! and Gears! Level them up and collect unique skins!\n\nBRAWL PASS\nComplete quests, open Brawl Boxes, earn Gems, pins and an exclusive Brawl Pass skin! Fresh content every season!\n\nBECOME THE STAR PLAYER\nClimb the local and regional leaderboards to prove you’re the greatest Brawler of them all!\n\nCONSTANTLY EVOLVING\nLook out for new Brawlers, skins, maps, special events and games modes in the future!\n\nPLEASE NOTE! Brawl Stars is free to download and play, however, some game items can also be purchased for real money. If you don’t want to use this feature, please disable in-app purchases in your device’s settings. Also, under our Terms of Service and Privacy Policy, you must be at least 9 years of age to play or download Brawl Stars.\n\nFeatures:\n- Team up for real-time 3v3 battles against players from across the world\n- A fast-paced multiplayer battle royale mode made for mobile\n- Unlock and collect new, powerful Brawlers - each with a signature attack and Super ability\n- New events and game modes daily\n- Battle solo or with friends\n- Climb to the top of the leaderboards in global and local rankings\n- Join or start your own Club with fellow players to share tips and battle together\n- Customize Brawlers with unlockable skins\n- Player-designed maps offer challenging new terrain to master\n\nFrom the makers of Clash of Clans, Clash Royale and Boom Beach!\n\nSupport:\nContact us in-game via Settings, Help and Support — or visit http://supercell.helpshift.com/a/brawl-stars/\n\nPrivacy Policy:\nhttp://supercell.com/en/privacy-policy/\n\nTerms of Service:\nhttp://supercell.com/en/terms-of-service/\n\nParent’s Guide:\nhttp://supercell.com/en/parents/\n\n#brawlstars #paintbrawl"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT52S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '3165597',
#     'likeCount': '137372',
#     'favoriteCount': '0',
#     'commentCount': '8401'}},
#   {'kind': 'youtube#video',
#    'etag': 'yrKyQoexAb8KyIGHpUCMl0CRyyU',
#    'id': 'aE10HERgL-4',
#    'snippet': {'publishedAt': '2024-08-01T08:00:00Z',
#     'channelId': 'UCD1Em4q90ZUK2R5HKesszJg',
#     'title': "It's Clash Anime Season! Happy 12th Clashiversary!",
#     'description': "Join us in celebrating our 12th Clashiversary by becoming the main character of the Anime season! We're sure you'll have a blast this season with exclusive anime-themed skins, scenery, decorations, events and more! Happy Clashiversary, Chiefs!\n\nFollow us on our Socials!\nTwitter ► https://twitter.com/ClashofClans/\nInstagram ► https://www.instagram.com/clashofclans \nFacebook ► https://www.facebook.com/ClashofClans \nTikTok ► https://www.tiktok.com/@clashofclans\n\nAttack. Defend. Strategize. Download for free for mobile devices. supr.cl/PlayClashOfClans\n\nFrom rage-\xadfilled Barbarians with glorious mustaches to pyromaniac wizards, raise your own army and lead your clan to victory! Build your village to fend off raiders, battle against millions of players worldwide, and forge a powerful clan with others to destroy enemy clans.\nPLEASE NOTE! Clash of Clans is free to download and play, however some game items can also be purchased for real money \n\nAlso, under our Terms of Service and Privacy Policy, you must be at least 13 years of age to play or download Clash of Clans.\nA network connection is also required.\n\nFEATURES\n- Build your village into an unbeatable fortress \n- Raise your own army of Barbarians, Archers, Hog Riders, Wizards, Dragons and other mighty fighters\n- Battle with players worldwide and take their Trophies\n- Join together with other players to form the ultimate Clan\n- Fight against rival Clans in epic Clan Wars \n- Build 18 unique units with multiple levels of upgrades\n- Discover your favorite attacking army from countless combinations of troops, spells, Heroes and Clan reinforcements \n- Defend your village with a multitude of Cannons, Towers, Mortars, Bombs, Traps and Walls\n- Fight against the Goblin King in a campaign through the realm\n\nChief, are you having problems? Visit https://help.supercellsupport.com/clash-of-clans/en/\n\nPrivacy Policy:\nhttps://supercell.com/en/privacy-policy/\n\nTerms of Service:\nhttps://supercell.com/en/terms-of-service/\n\nParent’s Guide:\nhttps://supercell.com/en/parents/\n\n#clashofclans #clashiversary #animeseason #animeshorts #animeedit",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/aE10HERgL-4/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/aE10HERgL-4/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/aE10HERgL-4/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/aE10HERgL-4/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/aE10HERgL-4/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Clash of Clans',
#     'tags': ['clash of clans',
#      'COC',
#      'Clash of Clans Gameplay',
#      'Clash of Clans Strategy',
#      'Clash of Clans Animation',
#      'Clash of Clans Commercial',
#      'Clash of Clans Attacks',
#      'Clash of Clans Town Hall',
#      'Hog Rider',
#      'PEKKA',
#      'Clan Wars',
#      'season challenges',
#      'clan war leagues',
#      'clash on',
#      'clan game',
#      'clan games',
#      'clash-a-rama',
#      'clasharama',
#      'clashiversary',
#      'anime short',
#      'anime trailer 2024',
#      'anime queen',
#      'anime king',
#      'clash of clans aniversary'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': "It's Clash Anime Season! Happy 12th Clashiversary!",
#      'description': "Join us in celebrating our 12th Clashiversary by becoming the main character of the Anime season! We're sure you'll have a blast this season with exclusive anime-themed skins, scenery, decorations, events and more! Happy Clashiversary, Chiefs!\n\nFollow us on our Socials!\nTwitter ► https://twitter.com/ClashofClans/\nInstagram ► https://www.instagram.com/clashofclans \nFacebook ► https://www.facebook.com/ClashofClans \nTikTok ► https://www.tiktok.com/@clashofclans\n\nAttack. Defend. Strategize. Download for free for mobile devices. supr.cl/PlayClashOfClans\n\nFrom rage-\xadfilled Barbarians with glorious mustaches to pyromaniac wizards, raise your own army and lead your clan to victory! Build your village to fend off raiders, battle against millions of players worldwide, and forge a powerful clan with others to destroy enemy clans.\nPLEASE NOTE! Clash of Clans is free to download and play, however some game items can also be purchased for real money \n\nAlso, under our Terms of Service and Privacy Policy, you must be at least 13 years of age to play or download Clash of Clans.\nA network connection is also required.\n\nFEATURES\n- Build your village into an unbeatable fortress \n- Raise your own army of Barbarians, Archers, Hog Riders, Wizards, Dragons and other mighty fighters\n- Battle with players worldwide and take their Trophies\n- Join together with other players to form the ultimate Clan\n- Fight against rival Clans in epic Clan Wars \n- Build 18 unique units with multiple levels of upgrades\n- Discover your favorite attacking army from countless combinations of troops, spells, Heroes and Clan reinforcements \n- Defend your village with a multitude of Cannons, Towers, Mortars, Bombs, Traps and Walls\n- Fight against the Goblin King in a campaign through the realm\n\nChief, are you having problems? Visit https://help.supercellsupport.com/clash-of-clans/en/\n\nPrivacy Policy:\nhttps://supercell.com/en/privacy-policy/\n\nTerms of Service:\nhttps://supercell.com/en/terms-of-service/\n\nParent’s Guide:\nhttps://supercell.com/en/parents/\n\n#clashofclans #clashiversary #animeseason #animeshorts #animeedit"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT35S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': False,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '3014088',
#     'likeCount': '121770',
#     'favoriteCount': '0',
#     'commentCount': '5715'}},
#   {'kind': 'youtube#video',
#    'etag': '0Wfqr9XR1XzO1BnMq8YdG0bJDEw',
#    'id': 'w6_GkG8ct_I',
#    'snippet': {'publishedAt': '2024-07-31T03:03:19Z',
#     'channelId': 'UC14UlmYlSNiQCBe9Eookf_A',
#     'title': 'HIGHLIGHTS | FC BARCELONA 2 (4 - 1) 2 MANCHESTER CITY | USA TOUR 2024',
#     'description': "The Blaugrana team starts the North American tour with a meritorious draw against City thanks to the goals of Pau Víctor and Pablo Torre in the first half.\n\nSUBSCRIBE NOW:\n▶ www.youtube.com/user/fcbarcelona \n\n📱 App: http://barca.link/kXum50R6rNO\n⚽ Barça One: http://barca.link/I32O50QVbj2\n🌐 Site: www.fcbarcelona.com\n\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n🔵 Facebook: http://www.facebook.com/fcbarcelona\n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/w6_GkG8ct_I/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/w6_GkG8ct_I/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/w6_GkG8ct_I/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/w6_GkG8ct_I/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/w6_GkG8ct_I/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'FC Barcelona',
#     'tags': ['FC Barcelona',
#      'برشلونة،',
#      'Fútbol',
#      'FUTBOL',
#      'soccer',
#      'FUTEBOL',
#      'Sepakbola',
#      'サッカー',
#      'كرة القدم',
#      'football',
#      'FCB',
#      'Barça',
#      'Sport',
#      'Club',
#      'ter stegen',
#      'goat',
#      'yt:cc=on',
#      'pedri',
#      'de Jong',
#      'lewandowski',
#      'spotify',
#      'kounde',
#      'Joao Felix',
#      'Joao Cancelo',
#      'Gavi',
#      'Lamine Yamal',
#      'Balde',
#      'Lewy',
#      'Lewandowski',
#      'Marc Guiu',
#      'Pau Cubarsí',
#      'CAMP NOU',
#      'Messi',
#      'Barcelona',
#      'Ronald',
#      'Araujo',
#      'Christensen',
#      'Fermín',
#      'Gündogan',
#      'Sergi Roberto',
#      'La Liga',
#      'Oriol Romeu',
#      'Frenkie',
#      'Héctor Fort',
#      'Manchester City',
#      'Guardiola',
#      'Hansi Flick',
#      'Highlights',
#      '2-2',
#      'Penalties',
#      '4-1',
#      'Haaland',
#      'Grealish'],
#     'categoryId': '17',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'en',
#     'localized': {'title': 'HIGHLIGHTS | FC BARCELONA 2 (4 - 1) 2 MANCHESTER CITY | USA TOUR 2024',
#      'description': "The Blaugrana team starts the North American tour with a meritorious draw against City thanks to the goals of Pau Víctor and Pablo Torre in the first half.\n\nSUBSCRIBE NOW:\n▶ www.youtube.com/user/fcbarcelona \n\n📱 App: http://barca.link/kXum50R6rNO\n⚽ Barça One: http://barca.link/I32O50QVbj2\n🌐 Site: www.fcbarcelona.com\n\n📸 Instagram: http://www.instagram.com/fcbarcelona\n𝕏 Twitter: http://twitter.com/FCBarcelona\n🎶 Tiktok: https://www.tiktok.com/@fcbarcelona \n🔵 Facebook: http://www.facebook.com/fcbarcelona\n👾 Discord: https://discord.gg/fcbarcelonaofficial\n\n🛍 Get all official Barça apparel from FC Barcelona's online store: http://barca.link/j8QH30qQh4Y \n🔵🔴 #FCBarcelona"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT3M29S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '4044039',
#     'likeCount': '102904',
#     'favoriteCount': '0',
#     'commentCount': '2569'}},
#   {'kind': 'youtube#video',
#    'etag': 'bBcLUhmKDv0ZsCe25vKR9-6VeTw',
#    'id': 'UHcbf6fESSQ',
#    'snippet': {'publishedAt': '2024-08-01T05:00:25Z',
#     'channelId': 'UC6-BgjsBa5R3PZQ_kZ8hKPg',
#     'title': 'LISA - ROCKSTAR Special Stage Performance (w/ HolyBang)',
#     'description': "Stream LISA's single 'Rockstar' now: http://LISA.lnk.to/ROCKSTAR\n\nFollow LISA:\nhttp://www.instagram.com/lalalalisa_m\nhttps://www.tiktok.com/@lalalalisa_m\nhttps://www.youtube.com/@lalalalisa_m\n\nFollow WeAreLLOUD:\nhttp://www.instagram.com/wearelloud\nhttps://www.tiktok.com/@wearelloud\nhttp://www.facebook.com/wearelloud\nhttps://www.youtube.com/@wearelloud\n\nFollow HolyBang (홀리뱅):\nhttps://www.instagram.com/play_holybang\nhttps://www.youtube.com/@holybang\n\nCredits:\n\nCreative Studio AEDIASTUDIO\n\nDirector XIMIN OH\n\nCreative Director AWKPAK, 102\nExecutive Producer SPEARMAN30\n\nProducer HANUL NA (NDP)\nLine Producer PYEONGAN YEON (NDP), YOUNGCHAE SONG (NDP)\nAssistant director MINYOUNG JEON, SUYEON KIM\n\nDOP GIUNG SEO\nFocus Puller SEUNGJONG LEE\n2nd HYUKJAE YANG\n3rd JUNSUNG CHA\nDIT HYUNBAE JEON\n\nGaffer BYUNGJU PARK\n1st JONGWON JEON\n2nd WOOHYEONG JEONG\n2nd YOUNGJAE KIM\n3rd JEONGPYO HAM\n3rd GYUNGMAN LEE\n\nArt Director GYUSEONG LIM\nArt Team JIHOON HAN\n\nJimmy Jib\nOperator KIM KI TAE \n1st JUNGHYUN BING\n2nd SEOKHOON KANG\n3rd GYUWON LEE\n\nShowlight J SHOW COMPANY \nJEON SUNG GANG\nJANG SUN HO\n\nEditor XIMIN OH\n\n3D Title Logo JIHO JEON (AEFX)\n\nColorist SOYEON KIM (VISION)\nCleaning MINYOUNG JEON, COMMA\n\nPA HANMIN LEE,MINHYEOK HONG, BYEONGCHEOL LEE, SUNGJIN KIM, YURI KIM",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/UHcbf6fESSQ/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/UHcbf6fESSQ/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/UHcbf6fESSQ/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/UHcbf6fESSQ/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/UHcbf6fESSQ/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'LLOUD Official',
#     'tags': ['Blackpink',
#      'Lisa',
#      'Music',
#      'Fashion',
#      'K-Pop',
#      'kpop',
#      'LLoud',
#      'dance',
#      'dancing',
#      'HolyBang',
#      'LISA ROCKSTAR performance',
#      'LISA performance',
#      'LISA ROCKSTAR',
#      'ROCKSTAR dance',
#      'LISA promo',
#      'LISA from Blackpink',
#      'LISA Blackpink tour movie'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'LISA - ROCKSTAR Special Stage Performance (w/ HolyBang)',
#      'description': "Stream LISA's single 'Rockstar' now: http://LISA.lnk.to/ROCKSTAR\n\nFollow LISA:\nhttp://www.instagram.com/lalalalisa_m\nhttps://www.tiktok.com/@lalalalisa_m\nhttps://www.youtube.com/@lalalalisa_m\n\nFollow WeAreLLOUD:\nhttp://www.instagram.com/wearelloud\nhttps://www.tiktok.com/@wearelloud\nhttp://www.facebook.com/wearelloud\nhttps://www.youtube.com/@wearelloud\n\nFollow HolyBang (홀리뱅):\nhttps://www.instagram.com/play_holybang\nhttps://www.youtube.com/@holybang\n\nCredits:\n\nCreative Studio AEDIASTUDIO\n\nDirector XIMIN OH\n\nCreative Director AWKPAK, 102\nExecutive Producer SPEARMAN30\n\nProducer HANUL NA (NDP)\nLine Producer PYEONGAN YEON (NDP), YOUNGCHAE SONG (NDP)\nAssistant director MINYOUNG JEON, SUYEON KIM\n\nDOP GIUNG SEO\nFocus Puller SEUNGJONG LEE\n2nd HYUKJAE YANG\n3rd JUNSUNG CHA\nDIT HYUNBAE JEON\n\nGaffer BYUNGJU PARK\n1st JONGWON JEON\n2nd WOOHYEONG JEONG\n2nd YOUNGJAE KIM\n3rd JEONGPYO HAM\n3rd GYUNGMAN LEE\n\nArt Director GYUSEONG LIM\nArt Team JIHOON HAN\n\nJimmy Jib\nOperator KIM KI TAE \n1st JUNGHYUN BING\n2nd SEOKHOON KANG\n3rd GYUWON LEE\n\nShowlight J SHOW COMPANY \nJEON SUNG GANG\nJANG SUN HO\n\nEditor XIMIN OH\n\n3D Title Logo JIHO JEON (AEFX)\n\nColorist SOYEON KIM (VISION)\nCleaning MINYOUNG JEON, COMMA\n\nPA HANMIN LEE,MINHYEOK HONG, BYEONGCHEOL LEE, SUNGJIN KIM, YURI KIM"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT2M17S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '2831636',
#     'likeCount': '477703',
#     'favoriteCount': '0',
#     'commentCount': '21561'}},
#   {'kind': 'youtube#video',
#    'etag': 'cgb3ZDAD_FnSv8sJJMgW9k_qBrE',
#    'id': 'XTuWgkF5lao',
#    'snippet': {'publishedAt': '2024-07-30T21:23:21Z',
#     'channelId': 'UCgTOIiEgjm58xLjHvDjmgdA',
#     'title': 'MI POV en un RETO de MRBEAST por $1.000.000',
#     'description': 'MI CANAL DE TWITCH https://www.twitch.tv/elspreen\n\n• Mi otro canal : https://www.youtube.com/channel/UC4DLCrt55UwaDvAswIr_59A\n\n● ¡Sigueme por aqui! 👀\n• Instagram: https://www.instagram.com/ivan_buhaje/\n• Twitter (Personal): https://twitter.com/ivan_buhaje\n• Twitter: https://twitter.com/SpreenDMC',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/XTuWgkF5lao/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/XTuWgkF5lao/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/XTuWgkF5lao/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/XTuWgkF5lao/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/XTuWgkF5lao/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Spreen',
#     'tags': ['Juego Spreen Español ARGENTINA',
#      'GRATIS',
#      'PRO',
#      'NOOB',
#      'SPREENDMC',
#      'SPREEN',
#      'PVP',
#      'ARGENTINA',
#      'ARGENTINO',
#      'CRAFT',
#      'EPICO',
#      'GRACISOSO',
#      'DIVERTIDO'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'MI POV en un RETO de MRBEAST por $1.000.000',
#      'description': 'MI CANAL DE TWITCH https://www.twitch.tv/elspreen\n\n• Mi otro canal : https://www.youtube.com/channel/UC4DLCrt55UwaDvAswIr_59A\n\n● ¡Sigueme por aqui! 👀\n• Instagram: https://www.instagram.com/ivan_buhaje/\n• Twitter (Personal): https://twitter.com/ivan_buhaje\n• Twitter: https://twitter.com/SpreenDMC'},
#     'defaultAudioLanguage': 'es-419'},
#    'contentDetails': {'duration': 'PT14M23S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1075105',
#     'likeCount': '82967',
#     'favoriteCount': '0',
#     'commentCount': '2391'}},
#   {'kind': 'youtube#video',
#    'etag': '4FaXTtMd6VJQQYqbKB0Q597FRjk',
#    'id': 'bzAIuSo9yGk',
#    'snippet': {'publishedAt': '2024-07-30T18:34:23Z',
#     'channelId': 'UCqfCJBfrFSO4tZM1LNZTBFQ',
#     'title': 'Gimnasia artística en vivo #Paris2024: Transmisión final por equipos femenil',
#     'description': 'No te pierdas toda la acción totalmente en vivo desde nuestros canales de YouTube. Sigue los Juegos Olímpicos #Paris2024 a través de la multiplataforma de Claro Sports, y te invitamos a interactuar en nuestras redes sociales usando el HT #ParísEsTuyo\r\n\r\nToda la cobertura de los Juegos Olímpicos\r\n\r\n▶️ Encuentra de los mejores videos de esta justa olímpica https://www.youtube.com/playlist?list=PLBpuIdeeb2X4ObLhgyUbHJGM6HSkYmIpE\r\n\r\n▶️ ¡No pierdas detalle de ningún evento! https://www.youtube.com/playlist?list=PLBpuIdeeb2X7HagQb6h3UW2empVC-6Pr9\r\n\r\n▶️ Disfruta EN VIVO de la cobertura 24/7 en todos nuestros canales https://www.youtube.com/playlist?list=PLBpuIdeeb2X5pZskcgGAj9_aixrJpMDNp\r\n\r\n¡Síguenos en nuestras redes sociales!\r\n\r\n🔴 X: https://x.com/clarosports\r\n🔴 Facebook: https://www.facebook.com/clarosports/\r\n🔴 Instagram: https://www.instagram.com/clarosports/\r\n🔴 Tik Tok: https://www.tiktok.com/@clarosports',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/bzAIuSo9yGk/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/bzAIuSo9yGk/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/bzAIuSo9yGk/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/bzAIuSo9yGk/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/bzAIuSo9yGk/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Claro Sports',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es-MX',
#     'localized': {'title': 'Gimnasia artística en vivo #Paris2024: Transmisión final por equipos femenil',
#      'description': 'No te pierdas toda la acción totalmente en vivo desde nuestros canales de YouTube. Sigue los Juegos Olímpicos #Paris2024 a través de la multiplataforma de Claro Sports, y te invitamos a interactuar en nuestras redes sociales usando el HT #ParísEsTuyo\r\n\r\nToda la cobertura de los Juegos Olímpicos\r\n\r\n▶️ Encuentra de los mejores videos de esta justa olímpica https://www.youtube.com/playlist?list=PLBpuIdeeb2X4ObLhgyUbHJGM6HSkYmIpE\r\n\r\n▶️ ¡No pierdas detalle de ningún evento! https://www.youtube.com/playlist?list=PLBpuIdeeb2X7HagQb6h3UW2empVC-6Pr9\r\n\r\n▶️ Disfruta EN VIVO de la cobertura 24/7 en todos nuestros canales https://www.youtube.com/playlist?list=PLBpuIdeeb2X5pZskcgGAj9_aixrJpMDNp\r\n\r\n¡Síguenos en nuestras redes sociales!\r\n\r\n🔴 X: https://x.com/clarosports\r\n🔴 Facebook: https://www.facebook.com/clarosports/\r\n🔴 Instagram: https://www.instagram.com/clarosports/\r\n🔴 Tik Tok: https://www.tiktok.com/@clarosports'},
#     'defaultAudioLanguage': 'es-419'},
#    'contentDetails': {'duration': 'PT2H15M',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'regionRestriction': {'allowed': ['AR',
#       'BO',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'GT',
#       'HN',
#       'MX',
#       'NI',
#       'PA',
#       'PE',
#       'PY',
#       'SV',
#       'UY',
#       'VE']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '2690991',
#     'likeCount': '19237',
#     'favoriteCount': '0',
#     'commentCount': '529'}},
#   {'kind': 'youtube#video',
#    'etag': 'LUfuUC7LDdUVpq8ieZH2RAXYutI',
#    'id': '4dxrScNseYI',
#    'snippet': {'publishedAt': '2024-07-31T14:20:59Z',
#     'channelId': 'UCr73PvhsxV8RCuzM60bSVwA',
#     'title': 'CRISIS EN VENEZUELA: La oposición se moviliza tras las protestas que dejan más muertes',
#     'description': 'Momento emitido el miércoles 31 de julio de 2024 en #EmpezarYuyito\n \n\n★ Suscribite al canal de #CiudadMagazine en YouTube → https://youtube.com/@ciudadmagazine',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/4dxrScNseYI/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/4dxrScNseYI/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/4dxrScNseYI/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/4dxrScNseYI/sddefault.jpg',
#       'width': 640,
#       'height': 480}},
#     'channelTitle': 'Ciudad Magazine',
#     'tags': ['yuyito gonzalez',
#      'empezar el día',
#      'amalia yuyito gonzález',
#      'pochi',
#      'gossipeame',
#      'facundo ventura',
#      'venezuela',
#      'oposicion',
#      'protestas'],
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': 'CRISIS EN VENEZUELA: La oposición se moviliza tras las protestas que dejan más muertes',
#      'description': 'Momento emitido el miércoles 31 de julio de 2024 en #EmpezarYuyito\n \n\n★ Suscribite al canal de #CiudadMagazine en YouTube → https://youtube.com/@ciudadmagazine'},
#     'defaultAudioLanguage': 'es-419'},
#    'contentDetails': {'duration': 'PT12M50S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '319723',
#     'likeCount': '5727',
#     'favoriteCount': '0',
#     'commentCount': '852'}},
#   {'kind': 'youtube#video',
#    'etag': 'eaE2lkAy45ROABmm5exPq_RuF5E',
#    'id': 'gQLqSDLOoNw',
#    'snippet': {'publishedAt': '2024-07-31T21:09:08Z',
#     'channelId': 'UCqfCJBfrFSO4tZM1LNZTBFQ',
#     'title': 'Natación - Semifinales y finales | 31 de julio 2024',
#     'description': 'No te pierdas toda la acción totalmente en vivo desde nuestros canales de YouTube. Sigue los Juegos Olímpicos #Paris2024 a través de la multiplataforma de Claro Sports, y te invitamos a interactuar en nuestras redes sociales usando el HT #ParísEsTuyo\r\n\r\nToda la cobertura de los Juegos Olímpicos\r\n\r\n▶️ Encuentra de los mejores videos de esta justa olímpica https://www.youtube.com/playlist?list=PLBpuIdeeb2X4ObLhgyUbHJGM6HSkYmIpE\r\n\r\n▶️ ¡No pierdas detalle de ningún evento! https://www.youtube.com/playlist?list=PLBpuIdeeb2X7HagQb6h3UW2empVC-6Pr9\r\n\r\n▶️ Disfruta EN VIVO de la cobertura 24/7 en todos nuestros canales https://www.youtube.com/playlist?list=PLBpuIdeeb2X5pZskcgGAj9_aixrJpMDNp\r\n\r\n¡Síguenos en nuestras redes sociales!\r\n\r\n🔴 X: https://x.com/clarosports\r\n🔴 Facebook: https://www.facebook.com/clarosports/\r\n🔴 Instagram: https://www.instagram.com/clarosports/\r\n🔴 Tik Tok: https://www.tiktok.com/@clarosports',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/gQLqSDLOoNw/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/gQLqSDLOoNw/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/gQLqSDLOoNw/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/gQLqSDLOoNw/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/gQLqSDLOoNw/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Claro Sports',
#     'categoryId': '24',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es-MX',
#     'localized': {'title': 'Natación - Semifinales y finales | 31 de julio 2024',
#      'description': 'No te pierdas toda la acción totalmente en vivo desde nuestros canales de YouTube. Sigue los Juegos Olímpicos #Paris2024 a través de la multiplataforma de Claro Sports, y te invitamos a interactuar en nuestras redes sociales usando el HT #ParísEsTuyo\r\n\r\nToda la cobertura de los Juegos Olímpicos\r\n\r\n▶️ Encuentra de los mejores videos de esta justa olímpica https://www.youtube.com/playlist?list=PLBpuIdeeb2X4ObLhgyUbHJGM6HSkYmIpE\r\n\r\n▶️ ¡No pierdas detalle de ningún evento! https://www.youtube.com/playlist?list=PLBpuIdeeb2X7HagQb6h3UW2empVC-6Pr9\r\n\r\n▶️ Disfruta EN VIVO de la cobertura 24/7 en todos nuestros canales https://www.youtube.com/playlist?list=PLBpuIdeeb2X5pZskcgGAj9_aixrJpMDNp\r\n\r\n¡Síguenos en nuestras redes sociales!\r\n\r\n🔴 X: https://x.com/clarosports\r\n🔴 Facebook: https://www.facebook.com/clarosports/\r\n🔴 Instagram: https://www.instagram.com/clarosports/\r\n🔴 Tik Tok: https://www.tiktok.com/@clarosports'},
#     'defaultAudioLanguage': 'es-419'},
#    'contentDetails': {'duration': 'PT2H36M51S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'regionRestriction': {'allowed': ['AR',
#       'BO',
#       'CL',
#       'CO',
#       'CR',
#       'DO',
#       'EC',
#       'GT',
#       'HN',
#       'MX',
#       'NI',
#       'PA',
#       'PE',
#       'PY',
#       'SV',
#       'UY',
#       'VE']},
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '1741894',
#     'likeCount': '11428',
#     'favoriteCount': '0',
#     'commentCount': '458'}},
#   {'kind': 'youtube#video',
#    'etag': 'lLhIWyz73XFhDevej6WmZk7_Ouw',
#    'id': '8lPKiloKl7A',
#    'snippet': {'publishedAt': '2024-07-29T21:45:00Z',
#     'channelId': 'UCp7wTrsCU7eICb5z69D3rwA',
#     'title': 'Las EMOCIONES de INTENSAMENTE Vs SUPER AUTOS 🥴💥🚗 Los COMPAS',
#     'description': 'El mejor editor de vídeo y grabador de juegos 4K/120 fps: https://bit.ly/4f73jAa\nEn el video de hoy, las emociones de intensamente 2, Tristeza, Temor, furia y alegría están muy enfadados por que creen que hemos secuestrado a Ansiedad, y quieren destruir a los compas Acenix  y Timba Vk, pero están tranquilos por que tienen super coches, como un camión pincho, varios tanques, la trituradora de autos, o Cacafuti para acabar con ellos, suscribete deja tu like y tu comentario, os dejo con el video teardawn destrucción a tope. inside out o del reves.\nSi os ha gustado este vídeo recomendarme a vuestros amigos, Se agradece muchísimo vuestra valoración y opinión (Comentarios, Likes, favoritos, etc.) y no os olvidéis de suscribiros si queréis ver más vídeos como este. Muchas gracias a todos. minecraft.\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😂۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n▓▓▓▒▒▒░░░  CANALES DE MIS COMPAÑEROS ░░░▒▒▒▓▓▓\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😂۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n🔵 Canal de Timba Vk: https://www.youtube.com/@TimbaVk\n🟢 Canal de Acenix: https://www.youtube.com/@Acenix\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😍۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n▓▓▓▒▒▒░░░  MIS REDES SOCIALES  ░░░▒▒▒▓▓▓\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😍۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n⭐ Canal principal: https://www.youtube.com/@TimbaVk\n📷 Instagram: https://www.instagram.com/timbavk/\n🐦 Twitter: https://twitter.com/Timba_Vk\n📱   TikTok: https://www.tiktok.com/@eltimbababy?l...\n💜 Twitch: https://www.twitch.tv/timbavk\n🟪 Sígueme en DISCORD: https://discord.gg/CHpWWazQ\n🛑 Correo de contacto: Timbavk@adamantagency.com\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n0:00 Intro\n1:14 DemoCreator\n2:39 TEARDOWN',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/8lPKiloKl7A/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/8lPKiloKl7A/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/8lPKiloKl7A/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/8lPKiloKl7A/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/8lPKiloKl7A/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'Timba Vk',
#     'tags': ['intensamente 2',
#      'intensamente',
#      'teardown',
#      'alegria',
#      'furia',
#      'ansiedad',
#      'ansiedad intensamente 2',
#      'tristeza',
#      'temor',
#      'timba',
#      'timba vk',
#      'acenix',
#      'inside out',
#      'inside out 2',
#      'del reves',
#      'del reves 2'],
#     'categoryId': '20',
#     'liveBroadcastContent': 'none',
#     'defaultLanguage': 'es',
#     'localized': {'title': 'Las EMOCIONES de INTENSAMENTE Vs SUPER AUTOS 🥴💥🚗 Los COMPAS',
#      'description': 'El mejor editor de vídeo y grabador de juegos 4K/120 fps: https://bit.ly/4f73jAa\nEn el video de hoy, las emociones de intensamente 2, Tristeza, Temor, furia y alegría están muy enfadados por que creen que hemos secuestrado a Ansiedad, y quieren destruir a los compas Acenix  y Timba Vk, pero están tranquilos por que tienen super coches, como un camión pincho, varios tanques, la trituradora de autos, o Cacafuti para acabar con ellos, suscribete deja tu like y tu comentario, os dejo con el video teardawn destrucción a tope. inside out o del reves.\nSi os ha gustado este vídeo recomendarme a vuestros amigos, Se agradece muchísimo vuestra valoración y opinión (Comentarios, Likes, favoritos, etc.) y no os olvidéis de suscribiros si queréis ver más vídeos como este. Muchas gracias a todos. minecraft.\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😂۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n▓▓▓▒▒▒░░░  CANALES DE MIS COMPAÑEROS ░░░▒▒▒▓▓▓\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😂۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n🔵 Canal de Timba Vk: https://www.youtube.com/@TimbaVk\n🟢 Canal de Acenix: https://www.youtube.com/@Acenix\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😍۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n▓▓▓▒▒▒░░░  MIS REDES SOCIALES  ░░░▒▒▒▓▓▓\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩😍۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n⭐ Canal principal: https://www.youtube.com/@TimbaVk\n📷 Instagram: https://www.instagram.com/timbavk/\n🐦 Twitter: https://twitter.com/Timba_Vk\n📱   TikTok: https://www.tiktok.com/@eltimbababy?l...\n💜 Twitch: https://www.twitch.tv/timbavk\n🟪 Sígueme en DISCORD: https://discord.gg/CHpWWazQ\n🛑 Correo de contacto: Timbavk@adamantagency.com\n▬▬▬▬▬▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬▬▬▬▬▬▬▬\n0:00 Intro\n1:14 DemoCreator\n2:39 TEARDOWN'},
#     'defaultAudioLanguage': 'es'},
#    'contentDetails': {'duration': 'PT18M58S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '661691',
#     'likeCount': '16411',
#     'favoriteCount': '0',
#     'commentCount': '527'}},
#   {'kind': 'youtube#video',
#    'etag': 'HTDr-oV5HsL2Pwx2IyFKpChjtBM',
#    'id': '7rr0-km4C0g',
#    'snippet': {'publishedAt': '2024-07-31T15:00:00Z',
#     'channelId': 'UCtiObj3CsEAdNU6ZPWDsddQ',
#     'title': "TOMORROW X TOGETHER Official Character 'PPULBATU'",
#     'description': "TOMORROW X TOGETHER Official Character 'PPULBATU' \n\nCredits:\nProduction: Studio Nuts\n\nConnect with TOMORROW X TOGETHER:\nhttps://txt.ibighit.com\nhttps://x.com/TXT_bighit\nhttps://x.com/TXT_members \nhttps://x.com/TXT_bighit_jp\nhttps://www.facebook.com/TXT.bighit\nhttps://www.instagram.com/txt_bighit\nhttps://www.tiktok.com/@txt.bighitent \nhttps://weverse.io/txt\nhttps://www.weibo.com/TXTbighit\nhttps://space.bilibili.com/3493085912763265/\nhttps://v.douyin.com/i6BytSNo/\n\n#투모로우바이투게더 #TOMORROW_X_TOGETHER #TXT \n#PPULBATU #TXT_PPULBATU",
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/7rr0-km4C0g/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/7rr0-km4C0g/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/7rr0-km4C0g/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/7rr0-km4C0g/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/7rr0-km4C0g/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': 'TOMORROW X TOGETHER OFFICIAL',
#     'tags': ['투모로우바이투게더',
#      'TOMORROW X TOGETHER',
#      'TXT',
#      '연준',
#      '수빈',
#      '휴닝카이',
#      '태현',
#      '범규',
#      'YEONJUN',
#      'SOOBIN',
#      'HUENINGKAI',
#      'TAEHYUN',
#      'BEOMGYU',
#      '빅히트뮤직'],
#     'categoryId': '10',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': "TOMORROW X TOGETHER Official Character 'PPULBATU'",
#      'description': "TOMORROW X TOGETHER Official Character 'PPULBATU' \n\nCredits:\nProduction: Studio Nuts\n\nConnect with TOMORROW X TOGETHER:\nhttps://txt.ibighit.com\nhttps://x.com/TXT_bighit\nhttps://x.com/TXT_members \nhttps://x.com/TXT_bighit_jp\nhttps://www.facebook.com/TXT.bighit\nhttps://www.instagram.com/txt_bighit\nhttps://www.tiktok.com/@txt.bighitent \nhttps://weverse.io/txt\nhttps://www.weibo.com/TXTbighit\nhttps://space.bilibili.com/3493085912763265/\nhttps://v.douyin.com/i6BytSNo/\n\n#투모로우바이투게더 #TOMORROW_X_TOGETHER #TXT \n#PPULBATU #TXT_PPULBATU"},
#     'defaultAudioLanguage': 'en'},
#    'contentDetails': {'duration': 'PT25S',
#     'dimension': '2d',
#     'definition': 'hd',
#     'caption': 'false',
#     'licensedContent': True,
#     'contentRating': {},
#     'projection': 'rectangular'},
#    'statistics': {'viewCount': '269396',
#     'likeCount': '55028',
#     'favoriteCount': '0',
#     'commentCount': '2808'}}],
#  'nextPageToken': 'CAoQAA',
#  'pageInfo': {'totalResults': 200, 'resultsPerPage': 10}}

# %%
import pandas as pd
from pandas import json_normalize

df = json_normalize(data['items'])
df
# Out:
#             kind                         etag           id  \
# 0  youtube#video  JRJrxp9FEUNPalxD6KZ7TyxkFVY  RJw3Y-3EBFo
# 1  youtube#video  yrKyQoexAb8KyIGHpUCMl0CRyyU  aE10HERgL-4
# 2  youtube#video  0Wfqr9XR1XzO1BnMq8YdG0bJDEw  w6_GkG8ct_I
# 3  youtube#video  bBcLUhmKDv0ZsCe25vKR9-6VeTw  UHcbf6fESSQ
# 4  youtube#video  cgb3ZDAD_FnSv8sJJMgW9k_qBrE  XTuWgkF5lao
# 5  youtube#video  4FaXTtMd6VJQQYqbKB0Q597FRjk  bzAIuSo9yGk
# 6  youtube#video  LUfuUC7LDdUVpq8ieZH2RAXYutI  4dxrScNseYI
# 7  youtube#video  eaE2lkAy45ROABmm5exPq_RuF5E  gQLqSDLOoNw
# 8  youtube#video  lLhIWyz73XFhDevej6WmZk7_Ouw  8lPKiloKl7A
# 9  youtube#video  HTDr-oV5HsL2Pwx2IyFKpChjtBM  7rr0-km4C0g
#
#     snippet.publishedAt         snippet.channelId  \
# 0  2024-08-01T09:01:54Z  UCooVYzDxdwTtGYAkcPmOgOw
# 1  2024-08-01T08:00:00Z  UCD1Em4q90ZUK2R5HKesszJg
# 2  2024-07-31T03:03:19Z  UC14UlmYlSNiQCBe9Eookf_A
# 3  2024-08-01T05:00:25Z  UC6-BgjsBa5R3PZQ_kZ8hKPg
# 4  2024-07-30T21:23:21Z  UCgTOIiEgjm58xLjHvDjmgdA
# 5  2024-07-30T18:34:23Z  UCqfCJBfrFSO4tZM1LNZTBFQ
# 6  2024-07-31T14:20:59Z  UCr73PvhsxV8RCuzM60bSVwA
# 7  2024-07-31T21:09:08Z  UCqfCJBfrFSO4tZM1LNZTBFQ
# 8  2024-07-29T21:45:00Z  UCp7wTrsCU7eICb5z69D3rwA
# 9  2024-07-31T15:00:00Z  UCtiObj3CsEAdNU6ZPWDsddQ
#
#                                        snippet.title  \
# 0     Brawl Stars Animation: PAINT BRAWL STARTS NOW!
# 1  It's Clash Anime Season! Happy 12th Clashivers...
# 2  HIGHLIGHTS | FC BARCELONA 2 (4 - 1) 2 MANCHEST...
# 3  LISA - ROCKSTAR Special Stage Performance (w/ ...
# 4        MI POV en un RETO de MRBEAST por $1.000.000
# 5  Gimnasia artística en vivo #Paris2024: Transmi...
# 6  CRISIS EN VENEZUELA: La oposición se moviliza ...
# 7  Natación - Semifinales y finales | 31 de julio...
# 8  Las EMOCIONES de INTENSAMENTE Vs SUPER AUTOS 🥴...
# 9  TOMORROW X TOGETHER Official Character 'PPULBATU'
#
#                                  snippet.description  \
# 0  🫧 WE'RE BRAWLING IN THE DEEP! 🫧\n\n🎨 The new P...
# 1  Join us in celebrating our 12th Clashiversary ...
# 2  The Blaugrana team starts the North American t...
# 3  Stream LISA's single 'Rockstar' now: http://LI...
# 4  MI CANAL DE TWITCH https://www.twitch.tv/elspr...
# 5  No te pierdas toda la acción totalmente en viv...
# 6  Momento emitido el miércoles 31 de julio de 20...
# 7  No te pierdas toda la acción totalmente en viv...
# 8  El mejor editor de vídeo y grabador de juegos ...
# 9  TOMORROW X TOGETHER Official Character 'PPULBA...
#
#                    snippet.thumbnails.default.url  \
# 0  https://i.ytimg.com/vi/RJw3Y-3EBFo/default.jpg
# 1  https://i.ytimg.com/vi/aE10HERgL-4/default.jpg
# 2  https://i.ytimg.com/vi/w6_GkG8ct_I/default.jpg
# 3  https://i.ytimg.com/vi/UHcbf6fESSQ/default.jpg
# 4  https://i.ytimg.com/vi/XTuWgkF5lao/default.jpg
# 5  https://i.ytimg.com/vi/bzAIuSo9yGk/default.jpg
# 6  https://i.ytimg.com/vi/4dxrScNseYI/default.jpg
# 7  https://i.ytimg.com/vi/gQLqSDLOoNw/default.jpg
# 8  https://i.ytimg.com/vi/8lPKiloKl7A/default.jpg
# 9  https://i.ytimg.com/vi/7rr0-km4C0g/default.jpg
#
#    snippet.thumbnails.default.width  snippet.thumbnails.default.height  ...  \
# 0                               120                                 90  ...
# 1                               120                                 90  ...
# 2                               120                                 90  ...
# 3                               120                                 90  ...
# 4                               120                                 90  ...
# 5                               120                                 90  ...
# 6                               120                                 90  ...
# 7                               120                                 90  ...
# 8                               120                                 90  ...
# 9                               120                                 90  ...
#
#   contentDetails.dimension  contentDetails.definition  contentDetails.caption  \
# 0                       2d                         hd                   false
# 1                       2d                         hd                   false
# 2                       2d                         hd                   false
# 3                       2d                         hd                   false
# 4                       2d                         hd                   false
# 5                       2d                         hd                   false
# 6                       2d                         hd                   false
# 7                       2d                         hd                   false
# 8                       2d                         hd                   false
# 9                       2d                         hd                   false
#
#   contentDetails.licensedContent  contentDetails.projection  \
# 0                           True                rectangular
# 1                          False                rectangular
# 2                           True                rectangular
# 3                           True                rectangular
# 4                           True                rectangular
# 5                           True                rectangular
# 6                           True                rectangular
# 7                           True                rectangular
# 8                           True                rectangular
# 9                           True                rectangular
#
#    statistics.viewCount statistics.likeCount  statistics.favoriteCount  \
# 0               3165597               137372                         0
# 1               3014088               121770                         0
# 2               4044039               102904                         0
# 3               2831636               477703                         0
# 4               1075105                82967                         0
# 5               2690991                19237                         0
# 6                319723                 5727                         0
# 7               1741894                11428                         0
# 8                661691                16411                         0
# 9                269396                55028                         0
#
#    statistics.commentCount           contentDetails.regionRestriction.allowed
# 0                     8401                                                NaN
# 1                     5715                                                NaN
# 2                     2569                                                NaN
# 3                    21561                                                NaN
# 4                     2391                                                NaN
# 5                      529  [AR, BO, CL, CO, CR, DO, EC, GT, HN, MX, NI, P...
# 6                      852                                                NaN
# 7                      458  [AR, BO, CL, CO, CR, DO, EC, GT, HN, MX, NI, P...
# 8                      527                                                NaN
# 9                     2808                                                NaN
#
# [10 rows x 41 columns]

# %%
new_index = ['titulo', 'canal_id','reproducciones','cantidad_de_likes','cantidad_comentarios','duración','lenguaje']
dfredshift = df[['snippet.title','snippet.channelId','statistics.viewCount','statistics.likeCount','statistics.commentCount','contentDetails.duration','snippet.defaultLanguage']]
dfredshift.columns=new_index
dfredshift
# Out:
#                                               titulo  \
# 0     Brawl Stars Animation: PAINT BRAWL STARTS NOW!
# 1  It's Clash Anime Season! Happy 12th Clashivers...
# 2  HIGHLIGHTS | FC BARCELONA 2 (4 - 1) 2 MANCHEST...
# 3  LISA - ROCKSTAR Special Stage Performance (w/ ...
# 4        MI POV en un RETO de MRBEAST por $1.000.000
# 5  Gimnasia artística en vivo #Paris2024: Transmi...
# 6  CRISIS EN VENEZUELA: La oposición se moviliza ...
# 7  Natación - Semifinales y finales | 31 de julio...
# 8  Las EMOCIONES de INTENSAMENTE Vs SUPER AUTOS 🥴...
# 9  TOMORROW X TOGETHER Official Character 'PPULBATU'
#
#                    canal_id reproducciones cantidad_de_likes  \
# 0  UCooVYzDxdwTtGYAkcPmOgOw        3165597            137372
# 1  UCD1Em4q90ZUK2R5HKesszJg        3014088            121770
# 2  UC14UlmYlSNiQCBe9Eookf_A        4044039            102904
# 3  UC6-BgjsBa5R3PZQ_kZ8hKPg        2831636            477703
# 4  UCgTOIiEgjm58xLjHvDjmgdA        1075105             82967
# 5  UCqfCJBfrFSO4tZM1LNZTBFQ        2690991             19237
# 6  UCr73PvhsxV8RCuzM60bSVwA         319723              5727
# 7  UCqfCJBfrFSO4tZM1LNZTBFQ        1741894             11428
# 8  UCp7wTrsCU7eICb5z69D3rwA         661691             16411
# 9  UCtiObj3CsEAdNU6ZPWDsddQ         269396             55028
#
#   cantidad_comentarios    duración lenguaje
# 0                 8401       PT52S       en
# 1                 5715       PT35S       en
# 2                 2569     PT3M29S       en
# 3                21561     PT2M17S      NaN
# 4                 2391    PT14M23S      NaN
# 5                  529     PT2H15M    es-MX
# 6                  852    PT12M50S      NaN
# 7                  458  PT2H36M51S    es-MX
# 8                  527    PT18M58S       es
# 9                 2808       PT25S      NaN

# %%
import isodate

def convert_to_minutes(duration):
    if pd.isna(duration):
        return None
    duration_obj = isodate.parse_duration(duration)
    return duration_obj.total_seconds() / 60



dfredshift['duración'] = dfredshift['duración'].apply(convert_to_minutes)


dfredshift
# Out:
# C:\Users\ariel\AppData\Local\Temp\ipykernel_3128\959362259.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfredshift['duración'] = dfredshift['duración'].apply(convert_to_minutes)
#                                               titulo  \
# 0     Brawl Stars Animation: PAINT BRAWL STARTS NOW!
# 1  It's Clash Anime Season! Happy 12th Clashivers...
# 2  HIGHLIGHTS | FC BARCELONA 2 (4 - 1) 2 MANCHEST...
# 3  LISA - ROCKSTAR Special Stage Performance (w/ ...
# 4        MI POV en un RETO de MRBEAST por $1.000.000
# 5  Gimnasia artística en vivo #Paris2024: Transmi...
# 6  CRISIS EN VENEZUELA: La oposición se moviliza ...
# 7  Natación - Semifinales y finales | 31 de julio...
# 8  Las EMOCIONES de INTENSAMENTE Vs SUPER AUTOS 🥴...
# 9  TOMORROW X TOGETHER Official Character 'PPULBATU'
#
#                    canal_id reproducciones cantidad_de_likes  \
# 0  UCooVYzDxdwTtGYAkcPmOgOw        3165597            137372
# 1  UCD1Em4q90ZUK2R5HKesszJg        3014088            121770
# 2  UC14UlmYlSNiQCBe9Eookf_A        4044039            102904
# 3  UC6-BgjsBa5R3PZQ_kZ8hKPg        2831636            477703
# 4  UCgTOIiEgjm58xLjHvDjmgdA        1075105             82967
# 5  UCqfCJBfrFSO4tZM1LNZTBFQ        2690991             19237
# 6  UCr73PvhsxV8RCuzM60bSVwA         319723              5727
# 7  UCqfCJBfrFSO4tZM1LNZTBFQ        1741894             11428
# 8  UCp7wTrsCU7eICb5z69D3rwA         661691             16411
# 9  UCtiObj3CsEAdNU6ZPWDsddQ         269396             55028
#
#   cantidad_comentarios    duración lenguaje
# 0                 8401    0.866667       en
# 1                 5715    0.583333       en
# 2                 2569    3.483333       en
# 3                21561    2.283333      NaN
# 4                 2391   14.383333      NaN
# 5                  529  135.000000    es-MX
# 6                  852   12.833333      NaN
# 7                  458  156.850000    es-MX
# 8                  527   18.966667       es
# 9                 2808    0.416667      NaN

# %%
from datetime import datetime
time_request = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
dfredshift['time_request'] = str(time_request)
dfredshift
# Out:
# C:\Users\ariel\AppData\Local\Temp\ipykernel_21352\1598177578.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfredshift['time_request'] = str(time_request)
#                                               titulo  \
# 0  Todo lo que dejaron las elecciones presidencia...
# 1  TNT Sports Replay | Colo Colo 2 - 1 O'Higgins ...
# 2  Tiro con arco en vivo #Paris2024: Cuartos, sem...
# 3                       Stray Kids "MOUNTAINS" Video
# 4  MADURO GANA ELECCIONES: primeras REACCIONES de...
# 5  Ceremonia de Inauguración de los Juegos Olímpi...
# 6  Surf #Paris2024 en vivo- Ronda 2 de los Juegos...
# 7       60 STREAMERS CONSTRUYEN por 1,000 DOLARES ⚠️
# 8  Escondí a Famosos en mis Fotos de Instagram y ...
# 9    RED BULL BARCELONA Cap.2 (Modo Carrera) FC 2024
#
#                    canal_id reproducciones cantidad_de_likes  \
# 0  UCuvM3c8rmdApmk-g22shZ7w         442720              4742
# 1  UChCovZlgNh2x6Z57MJ5fhFw         228836              2665
# 2  UCqfCJBfrFSO4tZM1LNZTBFQ         921284              6570
# 3  UC9rMiEjNaCSsebs31MRDCRA        2575691            565288
# 4  UCLtGUPjKLqa3zgdmhKCZONg         520584              6716
# 5  UCqfCJBfrFSO4tZM1LNZTBFQ        7786973            113519
# 6  UCqfCJBfrFSO4tZM1LNZTBFQ        2402208             15906
# 7  UCmDfpsIMjCw9bMrwa8dIsTw         172443             13053
# 8  UCapRTMkO4n3LP5dkmIayy5A         253369             33313
# 9  UC1StC0C68OdfjB9qyJPUF8A         741808             48909
#
#   cantidad_comentarios lenguaje         time_request
# 0                 1765      NaN  2024-07-29 20:15:00
# 1                  383      NaN  2024-07-29 20:15:00
# 2                   34    es-MX  2024-07-29 20:15:00
# 3                24348       en  2024-07-29 20:15:00
# 4                 4308       es  2024-07-29 20:15:00
# 5                 5560    es-MX  2024-07-29 20:15:00
# 6                  144    es-MX  2024-07-29 20:15:00
# 7                  160      NaN  2024-07-29 20:15:00
# 8                 2587      NaN  2024-07-29 20:15:00
# 9                  888      NaN  2024-07-29 20:15:00

# %%
dtypes= dfredshift.dtypes
cols= list(dtypes.index )
cols
# Out:
# ['titulo',
#  'canal_id',
#  'reproducciones',
#  'cantidad_de_likes',
#  'cantidad_comentarios',
#  'lenguaje',
#  'time_request']

# %%
values = [tuple(x) for x in dfredshift.to_numpy()]
values
# Out:
# [('Todo lo que dejaron las elecciones presidenciales en Venezuela',
#   'UCuvM3c8rmdApmk-g22shZ7w',
#   '442720',
#   '4742',
#   '1765',
#   nan,
#   '2024-07-29 20:15:00'),
#  ("TNT Sports Replay | Colo Colo 2 - 1 O'Higgins | Fecha 17",
#   'UChCovZlgNh2x6Z57MJ5fhFw',
#   '228836',
#   '2665',
#   '383',
#   nan,
#   '2024-07-29 20:15:00'),
#  ('Tiro con arco en vivo #Paris2024: Cuartos, semifinales y finales equipos varonil',
#   'UCqfCJBfrFSO4tZM1LNZTBFQ',
#   '921284',
#   '6570',
#   '34',
#   'es-MX',
#   '2024-07-29 20:15:00'),
#  ('Stray Kids "MOUNTAINS" Video',
#   'UC9rMiEjNaCSsebs31MRDCRA',
#   '2575691',
#   '565288',
#   '24348',
#   'en',
#   '2024-07-29 20:15:00'),
#  ('MADURO GANA ELECCIONES: primeras REACCIONES de VENEZOLANOS EN PERÚ tras RESULTADO | El Comercio',
#   'UCLtGUPjKLqa3zgdmhKCZONg',
#   '520584',
#   '6716',
#   '4308',
#   'es',
#   '2024-07-29 20:15:00'),
#  ('Ceremonia de Inauguración de los Juegos Olímpicos #Paris2024 en vivo',
#   'UCqfCJBfrFSO4tZM1LNZTBFQ',
#   '7786973',
#   '113519',
#   '5560',
#   'es-MX',
#   '2024-07-29 20:15:00'),
#  ('Surf #Paris2024 en vivo- Ronda 2 de los Juegos Olímpicos',
#   'UCqfCJBfrFSO4tZM1LNZTBFQ',
#   '2402208',
#   '15906',
#   '144',
#   'es-MX',
#   '2024-07-29 20:15:00'),
#  ('60 STREAMERS CONSTRUYEN por 1,000 DOLARES ⚠️',
#   'UCmDfpsIMjCw9bMrwa8dIsTw',
#   '172443',
#   '13053',
#   '160',
#   nan,
#   '2024-07-29 20:15:00'),
#  ('Escondí a Famosos en mis Fotos de Instagram y nadie se dio cuenta #2',
#   'UCapRTMkO4n3LP5dkmIayy5A',
#   '253369',
#   '33313',
#   '2587',
#   nan,
#   '2024-07-29 20:15:00'),
#  ('RED BULL BARCELONA Cap.2 (Modo Carrera) FC 2024',
#   'UC1StC0C68OdfjB9qyJPUF8A',
#   '741808',
#   '48909',
#   '888',
#   nan,
#   '2024-07-29 20:15:00')]

# %%
import psycopg2
from psycopg2.extras import execute_values

db_user = os.getenv('db_user')
db_password = os.getenv('db_password')
db_host_amazon = os.getenv('db_host_amazon')
db_port = os.getenv('db_port')
db_name = os.getenv('db_name')

conn = psycopg2.connect(
    host=db_host_amazon,
    dbname=db_name,
    user=db_user,
    password=db_password,
    port=db_port
)

# %%
query_create_table = f"""
    CREATE TABLE ariel_beaz_coderhouse.tendencias_youtube (
    titulo VARCHAR(500),
    canal_id VARCHAR(200),
    reproducciones INT,
    cantidad_de_likes INT,
    cantidad_comentarios INT,
    lenguaje VARCHAR(200),
    time_request VARCHAR(200)
);
"""

cur = conn.cursor()
cur.execute(query_create_table)
# Out:
# ---------------------------------------------------------------------------
# DuplicateTable                            Traceback (most recent call last)
# Cell In[112], line 14
#       1 query_create_table = f"""
#       2     CREATE TABLE ariel_beaz_coderhouse.tendencias_youtube (
#       3     titulo VARCHAR(500),
#    (...)
#      10 );
#      11 """
#      13 cur = conn.cursor()
# ---> 14 cur.execute(query_create_table)
#
# DuplicateTable: Relation "tendencias_youtube" already exists

# %%
insert_sql = f"INSERT INTO ariel_beaz_coderhouse.tendencias_youtube({', '.join(cols)}) VALUES %s"

cur.execute("BEGIN")
execute_values(cur, insert_sql, values)
cur.execute("COMMIT")
# Out:
# ---------------------------------------------------------------------------
# InFailedSqlTransaction                    Traceback (most recent call last)
# Cell In[115], line 3
#       1 insert_sql = f"INSERT INTO ariel_beaz_coderhouse.tendencias_youtube({', '.join(cols)}) VALUES %s"
# ----> 3 cur.execute("BEGIN")
#       4 execute_values(cur, insert_sql, values)
#       5 cur.execute("COMMIT")
#
# InFailedSqlTransaction: current transaction is aborted, commands ignored until end of transaction block

# %%
query_select = "SELECT * FROM ariel_beaz_coderhouse.tendencias_youtube limit 5;"
cursor.execute(query_select)

results = cursor.fetchall()
for row in results:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# Cell In[118], line 2
#       1 query_select = "SELECT * FROM ariel_beaz_coderhouse.tendencias_youtube limit 5;"
# ----> 2 cursor.execute(query_select)
#       4 results = cursor.fetchall()
#       5 for row in results:
#
# File c:\Users\ariel\AppData\Local\Programs\Python\Python310\lib\site-packages\redshift_connector\cursor.py:224, in Cursor.execute(self, operation, args, stream, merge_socket_read)
#     192 """Executes a database operation.  Parameters may be provided as a
#     193 sequence, or as a mapping, depending upon the value of
#     194 :data:`paramstyle`.
#    (...)
#     221
#     222 """
#     223 if self._c is None:
# --> 224     raise InterfaceError("Cursor closed")
#     225 if self._c._sock is None:
#     226     raise InterfaceError("connection is closed")
#
# InterfaceError: Cursor closed
